# %% [markdown]
# # Titanic Startup

# %% [markdown]
# **import lib**

# %%
import pandas as pd
import numpy as np
# from scikit-learn import train_test_split()
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# Load test and train data

# %%
train_data = pd.read_csv('../input/dataset/train.csv')
test_data = pd.read_csv('../input/dataset/test.csv')

# %%
#pre process data make data ready to ml model
def preprocess1(df):
    df['Sex'] = df['Sex'].map({'male': 0, 'female': 1})
    df['Age'] = df['Age'].fillna(df['Age'].median())
    df['Embarked'] = df['Embarked'].fillna('S')
    df['Embarked'] = df['Embarked'].map({'S': 0, 'C': 1, 'Q': 2})
    df['FamilySize'] = df['SibSp'] + df['Parch'] + 1
    return df

# %%
#check null values
train_data.isna().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
train_data = preprocess1(train_data)

# %%
train_data = preprocess2(train_data)

# %%
train_data['Embarked'].unique()
# Out:
# array([0, 1, 2])

# %%
features = ['Pclass', 'Sex', 'Age', 'Embarked', 'FamilySize']
# features = ['PClass', 'Sex', 'Age', 'Fare', 'Embarked', 'FamilySize']

# %%
non_numeric_fares = train_data[~train_data['Fare'].apply(lambda x: isinstance(x, (int, float)))]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/AI/competion/titanic/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Fare'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[259], line 1
# ...

# %%
print(non_numeric_fares)
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Sex, Age, SibSp, Parch, Fare, Embarked]
# Index: []

# %%
train_data['Fare'] = pd.to_numeric(train_data['Fare'], errors='coerce')

# %%
def preprocess2(df):
    df.drop('Name', axis=1, inplace=True)
    df.drop('Fare', axis=1, inplace=True)
    df.drop('Cabin', axis=1, inplace=True)
    df.drop('Ticket', axis=1, inplace=True)
    return df

# %%
test_data.isna().any()
# Out:
# PassengerId    False
# Pclass         False
# Sex            False
# Age            False
# SibSp          False
# Parch          False
# Embarked       False
# FamilySize     False
# dtype: bool

# %%
test_data = preprocess1(test_data)

# %%
test_data = preprocess2(test_data)

# %%
test_data
# Out:
#      PassengerId  Pclass  ... Cabin Embarked
# 0            892       3  ...   NaN        Q
# 1            893       3  ...   NaN        S
# 2            894       2  ...   NaN        Q
# 3            895       3  ...   NaN        S
# 4            896       3  ...   NaN        S
# ..           ...     ...  ...   ...      ...
# 413         1305       3  ...   NaN        S
# 414         1306       1  ...  C105        C
# 415         1307       3  ...   NaN        S
# 416         1308       3  ...   NaN        S
# 417         1309       3  ...   NaN        C
#
# [418 rows x 11 columns]

# %%
X = train_data[features]

# %%
train_data
# Out:
#      PassengerId  Survived  Pclass  Sex  ...  SibSp  Parch  Embarked  FamilySize
# 0              1         0       3    0  ...      1      0         0           2
# 1              2         1       1    1  ...      1      0         1           2
# 2              3         1       3    1  ...      0      0         0           1
# 3              4         1       1    1  ...      1      0         0           2
# 4              5         0       3    0  ...      0      0         0           1
# ..           ...       ...     ...  ...  ...    ...    ...       ...         ...
# 886          887         0       2    0  ...      0      0         0           1
# 887          888         1       1    1  ...      0      0         0           1
# 888          889         0       3    1  ...      1      2         0           4
# 889          890         1       1    0  ...      0      0         1           1
# 890          891         0       3    0  ...      0      0         2           1
#
# ...

# %%
Y=train_data['Survived']

# %%
Y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
#Train Model

model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X,Y)
# Out:
# RandomForestClassifier(random_state=42)

# %%
#Predict and Submit

X_test = test_data[features]

# %%
X_test
# Out:
#      Pclass  Sex   Age  Embarked  FamilySize
# 0         3    0  34.5         2           1
# 1         3    1  47.0         0           2
# 2         2    0  62.0         2           1
# 3         3    0  27.0         0           1
# 4         3    1  22.0         0           3
# ..      ...  ...   ...       ...         ...
# 413       3    0  27.0         0           1
# 414       1    1  39.0         1           1
# 415       3    0  38.5         0           1
# 416       3    0  27.0         0           1
# 417       3    0  27.0         1           3
#
# [418 rows x 5 columns]

# %%
predictions = model.predict(X_test)

# %%
submission = pd.DataFrame({
    'PassengerId':test_data['PassengerId'],
    'Survived':predictions
})

# %%
submission
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         1
# 4            896         1
# ..           ...       ...
# 413         1305         1
# 414         1306         1
# 415         1307         0
# 416         1308         1
# 417         1309         1
#
# [418 rows x 2 columns]

# %% [markdown]
# Generate csv for upload

# %%
submission.to_csv('submission.csv', index=False)

# %%
model.score(X,Y)
# Out:
# 0.9315375982042648

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[261], line 1
# ----> 1 from xgboost import XGBClassifier
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
import lightgbm as lgb

# %%
from sklearn import datasets

# %%
hand = datasets.load_digits()

# %%
exit()
